# %%
import pandas as pd

# %%
df = pd.read_csv('world_alcohol - world_alcohol.csv')

# %%
filtered_df_avg_consumption = df[(df['Display Value'] >= 0.5) & (df['Display Value'] <= 2.5)]

filtered_df_avg_consumption
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 2   1985                 Africa
# 4   1987               Americas
# 8   1986               Americas
# 11  1989               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 32  1989                 Africa
# 34  1986                 Europe
# 35  1985               Americas
# 40  1987                 Europe
# 46  1987               Americas
# 48  1987               Americas
# 49  1986                 Europe
# 54  1984               Americas
# 64  1989               Americas
# 70  1986                 Africa
# 71  1985                 Africa
# 74  1986               Americas
# 79  1989                 Europe
# 80  1985                 Africa
# 82  1987                 Europe
# 86  1986               Americas
# 89  1986  Eastern Mediterranean
#
# ...
