# %% [markdown]
# Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight dataframe’s specific columns with different colors.

# %%
import pandas as pd
import numpy as np

# %%
random_data = pd.DataFrame(np.random.randn(10, 3), columns=['A', 'B', 'C'])

def highlight_columns(s):
    if s.name == 'A':
        return ['background-color: blue'] * len(s)
    elif s.name == 'B':
        return ['background-color: green'] * len(s)
    elif s.name == 'C':
        return ['background-color: red'] * len(s)
    else:
        return [''] * len(s)

styled_df_columns = random_data.style.apply(highlight_columns, axis=0)

styled_df_columns
# Out:
# <style type="text/css">
# #T_8db88_row0_col0, #T_8db88_row1_col0, #T_8db88_row2_col0, #T_8db88_row3_col0, #T_8db88_row4_col0, #T_8db88_row5_col0, #T_8db88_row6_col0, #T_8db88_row7_col0, #T_8db88_row8_col0, #T_8db88_row9_col0 {
#   background-color: blue;
# }
# #T_8db88_row0_col1, #T_8db88_row1_col1, #T_8db88_row2_col1, #T_8db88_row3_col1, #T_8db88_row4_col1, #T_8db88_row5_col1, #T_8db88_row6_col1, #T_8db88_row7_col1, #T_8db88_row8_col1, #T_8db88_row9_col1 {
#   background-color: green;
# }
# #T_8db88_row0_col2, #T_8db88_row1_col2, #T_8db88_row2_col2, #T_8db88_row3_col2, #T_8db88_row4_col2, #T_8db88_row5_col2, #T_8db88_row6_col2, #T_8db88_row7_col2, #T_8db88_row8_col2, #T_8db88_row9_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_8db88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8db88_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8db88_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_8db88_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8db88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8db88_row0_col0" class="data row0 col0" >0.242371</td>
#       <td id="T_8db88_row0_col1" class="data row0 col1" >1.695271</td>
#       <td id="T_8db88_row0_col2" class="data row0 col2" >-1.318647</td>
#     </tr>
#     <tr>
#       <th id="T_8db88_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8db88_row1_col0" class="data row1 col0" >1.201465</td>
#       <td id="T_8db88_row1_col1" class="data row1 col1" >-0.869819</td>
#       <td id="T_8db88_row1_col2" class="data row1 col2" >-1.746713</td>
#     </tr>
#     <tr>
#       <th id="T_8db88_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8db88_row2_col0" class="data row2 col0" >-1.559107</td>
#       <td id="T_8db88_row2_col1" class="data row2 col1" >-1.345880</td>
#       <td id="T_8db88_row2_col2" class="data row2 col2" >0.421217</td>
#     </tr>
#     <tr>
#       <th id="T_8db88_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8db88_row3_col0" class="data row3 col0" >1.534183</td>
#       <td id="T_8db88_row3_col1" class="data row3 col1" >-0.631236</td>
#       <td id="T_8db88_row3_col2" class="data row3 col2" >-1.833480</td>
#     </tr>
#     <tr>
#       <th id="T_8db88_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8db88_row4_col0" class="data row4 col0" >0.425574</td>
#       <td id="T_8db88_row4_col1" class="data row4 col1" >-2.113207</td>
#       <td id="T_8db88_row4_col2" class="data row4 col2" >-1.202774</td>
#     </tr>
#     <tr>
#       <th id="T_8db88_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8db88_row5_col0" class="data row5 col0" >-0.677822</td>
#       <td id="T_8db88_row5_col1" class="data row5 col1" >-0.524445</td>
#       <td id="T_8db88_row5_col2" class="data row5 col2" >0.300749</td>
#     </tr>
#     <tr>
#       <th id="T_8db88_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8db88_row6_col0" class="data row6 col0" >0.701489</td>
#       <td id="T_8db88_row6_col1" class="data row6 col1" >-1.439826</td>
#       <td id="T_8db88_row6_col2" class="data row6 col2" >-1.479001</td>
#     </tr>
#     <tr>
#       <th id="T_8db88_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8db88_row7_col0" class="data row7 col0" >-0.760732</td>
#       <td id="T_8db88_row7_col1" class="data row7 col1" >-0.192227</td>
#       <td id="T_8db88_row7_col2" class="data row7 col2" >-0.964407</td>
#     </tr>
#     <tr>
#       <th id="T_8db88_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8db88_row8_col0" class="data row8 col0" >-0.557829</td>
#       <td id="T_8db88_row8_col1" class="data row8 col1" >-0.791002</td>
#       <td id="T_8db88_row8_col2" class="data row8 col2" >-0.686771</td>
#     </tr>
#     <tr>
#       <th id="T_8db88_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8db88_row9_col0" class="data row9 col0" >-0.237084</td>
#       <td id="T_8db88_row9_col1" class="data row9 col1" >0.960043</td>
#       <td id="T_8db88_row9_col2" class="data row9 col2" >-0.699414</td>
#     </tr>
#   </tbody>
# </table>

# %%
heatmap_styled_df = random_data.style.background_gradient(cmap='viridis')

heatmap_styled_df
# Out:
# <style type="text/css">
# #T_feeb5_row0_col0 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_feeb5_row0_col1, #T_feeb5_row2_col2, #T_feeb5_row3_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_feeb5_row0_col2 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_feeb5_row1_col0 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_feeb5_row1_col1 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_feeb5_row1_col2 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_feeb5_row2_col0, #T_feeb5_row3_col2, #T_feeb5_row4_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_feeb5_row2_col1 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_feeb5_row3_col1 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_feeb5_row4_col0 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_feeb5_row4_col2 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_feeb5_row5_col0 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_feeb5_row5_col1 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_feeb5_row5_col2 {
#   background-color: #dde318;
#   color: #000000;
# }
# #T_feeb5_row6_col0 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_feeb5_row6_col1 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_feeb5_row6_col2 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_feeb5_row7_col0 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_feeb5_row7_col1, #T_feeb5_row8_col2 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_feeb5_row7_col2 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_feeb5_row8_col0 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_feeb5_row8_col1 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_feeb5_row9_col0 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_feeb5_row9_col1 {
#   background-color: #7fd34e;
#   color: #000000;
# }
# #T_feeb5_row9_col2 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_feeb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_feeb5_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_feeb5_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_feeb5_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_feeb5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_feeb5_row0_col0" class="data row0 col0" >0.242371</td>
#       <td id="T_feeb5_row0_col1" class="data row0 col1" >1.695271</td>
#       <td id="T_feeb5_row0_col2" class="data row0 col2" >-1.318647</td>
#     </tr>
#     <tr>
#       <th id="T_feeb5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_feeb5_row1_col0" class="data row1 col0" >1.201465</td>
#       <td id="T_feeb5_row1_col1" class="data row1 col1" >-0.869819</td>
#       <td id="T_feeb5_row1_col2" class="data row1 col2" >-1.746713</td>
#     </tr>
#     <tr>
#       <th id="T_feeb5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_feeb5_row2_col0" class="data row2 col0" >-1.559107</td>
#       <td id="T_feeb5_row2_col1" class="data row2 col1" >-1.345880</td>
#       <td id="T_feeb5_row2_col2" class="data row2 col2" >0.421217</td>
#     </tr>
#     <tr>
#       <th id="T_feeb5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_feeb5_row3_col0" class="data row3 col0" >1.534183</td>
#       <td id="T_feeb5_row3_col1" class="data row3 col1" >-0.631236</td>
#       <td id="T_feeb5_row3_col2" class="data row3 col2" >-1.833480</td>
#     </tr>
#     <tr>
#       <th id="T_feeb5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_feeb5_row4_col0" class="data row4 col0" >0.425574</td>
#       <td id="T_feeb5_row4_col1" class="data row4 col1" >-2.113207</td>
#       <td id="T_feeb5_row4_col2" class="data row4 col2" >-1.202774</td>
#     </tr>
#     <tr>
#       <th id="T_feeb5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_feeb5_row5_col0" class="data row5 col0" >-0.677822</td>
#       <td id="T_feeb5_row5_col1" class="data row5 col1" >-0.524445</td>
#       <td id="T_feeb5_row5_col2" class="data row5 col2" >0.300749</td>
#     </tr>
#     <tr>
#       <th id="T_feeb5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_feeb5_row6_col0" class="data row6 col0" >0.701489</td>
#       <td id="T_feeb5_row6_col1" class="data row6 col1" >-1.439826</td>
#       <td id="T_feeb5_row6_col2" class="data row6 col2" >-1.479001</td>
#     </tr>
#     <tr>
#       <th id="T_feeb5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_feeb5_row7_col0" class="data row7 col0" >-0.760732</td>
#       <td id="T_feeb5_row7_col1" class="data row7 col1" >-0.192227</td>
#       <td id="T_feeb5_row7_col2" class="data row7 col2" >-0.964407</td>
#     </tr>
#     <tr>
#       <th id="T_feeb5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_feeb5_row8_col0" class="data row8 col0" >-0.557829</td>
#       <td id="T_feeb5_row8_col1" class="data row8 col1" >-0.791002</td>
#       <td id="T_feeb5_row8_col2" class="data row8 col2" >-0.686771</td>
#     </tr>
#     <tr>
#       <th id="T_feeb5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_feeb5_row9_col0" class="data row9 col0" >-0.237084</td>
#       <td id="T_feeb5_row9_col1" class="data row9 col1" >0.960043</td>
#       <td id="T_feeb5_row9_col2" class="data row9 col2" >-0.699414</td>
#     </tr>
#   </tbody>
# </table>
